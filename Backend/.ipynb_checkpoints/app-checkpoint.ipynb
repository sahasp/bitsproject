# %%
#CHATBOT MODEL
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")

#CHATBOT MODEL
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Training data created
# <ipython-input-1-5aedf1a20323>:74: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# C:\Users\Sahas\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 10/10 [==============================] - 3s 10ms/step - loss: 2.2323 - accuracy: 0.1702
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1547 - accuracy: 0.1915
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0469 - accuracy: 0.2979
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9773 - accuracy: 0.2766
# Epoch 5/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8860 - accuracy: 0.4255
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6356 - accuracy: 0.6383
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5766 - accuracy: 0.4468
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4589 - accuracy: 0.4894
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4141 - accuracy: 0.4681
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2868 - accuracy: 0.6383
# Epoch 11/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1458 - accuracy: 0.7447
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0713 - accuracy: 0.6809
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0486 - accuracy: 0.6809
# Epoch 14/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8038 - accuracy: 0.7872
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7322 - accuracy: 0.7660
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7977 - accuracy: 0.7234
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7361 - accuracy: 0.7872
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5552 - accuracy: 0.8511
# Epoch 19/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4763 - accuracy: 0.9149
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5486 - accuracy: 0.8511
# Epoch 21/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5675 - accuracy: 0.8936
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4915 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3158 - accuracy: 0.9149
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3335 - accuracy: 0.9362
# Epoch 25/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3186 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3703 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8511
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.9787
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3249 - accuracy: 0.8511
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3120 - accuracy: 0.9362
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1483 - accuracy: 1.0000
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2214 - accuracy: 0.9787
# Epoch 33/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.9787
# Epoch 34/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1323 - accuracy: 1.0000
# Epoch 35/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1963 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3168 - accuracy: 0.8936
# Epoch 37/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1967 - accuracy: 0.9362
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2292 - accuracy: 0.9362
# Epoch 40/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9149
# Epoch 42/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1253 - accuracy: 1.0000
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1262 - accuracy: 1.0000
# Epoch 44/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1563 - accuracy: 0.9362
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1285 - accuracy: 0.9574
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1330 - accuracy: 0.9574
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9574
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1020 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0714 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2241 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1478 - accuracy: 0.9362
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0527 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1731 - accuracy: 0.9574
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1058 - accuracy: 0.9574
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9574
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1048 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9787
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9574
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0554 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9787
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9787
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9787
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9574
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 0.9787
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0445 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9787
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9362
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9574
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9787
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9787
# Epoch 190/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9787
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9574
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 1.0000
# model created

# %%
#CHATBOT UI
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
    
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
            
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("SWYM - Clinical Trial Support")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
#CHATBOT
# Out:
# 1/1 [==============================] - 0s 163ms/step

# %%
import translators as ts
from profanity_check import predict
from flask import Flask, request, jsonify
from flask_cors import CORS
app = Flask(__name__)
cors = CORS(app)
#APIs
#Create the receiver API POST endpoint:
@app.route("/translate", methods=["POST"])
def translate():
    data = request.get_json()
    print(data[0])
    phrase = data[0]['data']
    lang = data[0]['lang']
    from_lang = "en" if lang == "fr" else "fr"
    data = jsonify([{'data': ts.google(phrase, from_language=from_lang, to_language=lang)}])
    return data
@app.route("/offensive", methods=["POST"])
def offensive():
    data = request.get_json()
    print(data[0])
    phrase = data[0]['data']
    prediction = predict([phrase])[0]
    data = jsonify([{'data': str(prediction)}])
    return data

if __name__ == "__main__": 
    app.run()
#APIs
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
#Text SUmmarization

#Text SUmmarization
