# %%
#CHATBOT MODEL
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")

#CHATBOT MODEL
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Training data created
# Epoch 1/200
# <ipython-input-2-5aedf1a20323>:74: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# C:\Users\Sahas\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 10/10 [==============================] - 1s 3ms/step - loss: 2.2114 - accuracy: 0.1064
# Epoch 2/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1586 - accuracy: 0.1064
# Epoch 3/200
# 10/10 [==============================] - 0s 7ms/step - loss: 2.1403 - accuracy: 0.1489
# Epoch 4/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9823 - accuracy: 0.2979
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9150 - accuracy: 0.4255
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8080 - accuracy: 0.3830
# Epoch 7/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.6866 - accuracy: 0.4894
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5732 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5014 - accuracy: 0.4894
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4692 - accuracy: 0.5532
# Epoch 11/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1457 - accuracy: 0.7234
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2501 - accuracy: 0.5957
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9803 - accuracy: 0.7447
# Epoch 14/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8616 - accuracy: 0.7660
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8233 - accuracy: 0.7872
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8004 - accuracy: 0.8085
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7593 - accuracy: 0.7447
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7917 - accuracy: 0.7660
# Epoch 19/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7977 - accuracy: 0.7447
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6009 - accuracy: 0.7660
# Epoch 21/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5314 - accuracy: 0.8936
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5581 - accuracy: 0.8085
# Epoch 23/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4823 - accuracy: 0.8298
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4815 - accuracy: 0.8511
# Epoch 25/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3909 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2668 - accuracy: 0.9787
# Epoch 27/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3867 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3949 - accuracy: 0.8936
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3156 - accuracy: 0.8723
# Epoch 30/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2924 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.9574
# Epoch 32/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2370 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3009 - accuracy: 0.9362
# Epoch 34/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.9574
# Epoch 35/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1932 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1027 - accuracy: 0.9787
# Epoch 37/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3014 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2658 - accuracy: 0.9362
# Epoch 39/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1640 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1244 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1576 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2423 - accuracy: 0.9149
# Epoch 44/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1885 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0747 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1912 - accuracy: 0.9149
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1414 - accuracy: 0.9362
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1175 - accuracy: 0.9574
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9362
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1503 - accuracy: 0.9574
# Epoch 53/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1344 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1032 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1332 - accuracy: 0.9362
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9362
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.9149
# Epoch 79/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9574
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1415 - accuracy: 0.9362
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0797 - accuracy: 0.9574
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.9574
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9787
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0714 - accuracy: 0.9787
# Epoch 132/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1803 - accuracy: 0.9787
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9362
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0868 - accuracy: 0.9574
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9787
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9787
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9574
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9787
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 183/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9787
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
# model created

# %%
#CHATBOT UI
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
    
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
            
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("SWYM - Clinical Trial Support")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
#CHATBOT
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
import translators as ts
from profanity_check import predict
from flask import Flask, request, jsonify
from flask_cors import CORS
app = Flask(__name__)
cors = CORS(app)
#APIs
#Create the receiver API POST endpoint:
@app.route("/translate", methods=["POST"])
def translate():
    data = request.get_json()
    print(data[0])
    phrase = data[0]['data']
    data = jsonify([{'data': ts.google(phrase, from_language='en', to_language='fr')}])
    return data
@app.route("/offensive", methods=["POST"])
def offensive():
    data = request.get_json()
    print(data[0])
    phrase = data[0]['data']
    prediction = predict([phrase])[0]
    data = jsonify([{'data': str(prediction)}])
    return data

if __name__ == "__main__": 
    app.run()
#APIs
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [30/Jun/2022 23:15:03] "OPTIONS /translate HTTP/1.1" 200 -
# {'data': "World's most beautiful car in Curabitur the most beatuiful car available in america and the saudia arabia, you can book your test drive by our official website"}
# 127.0.0.1 - - [30/Jun/2022 23:15:05] "POST /translate HTTP/1.1" 200 -

# %%
#Text SUmmarization

#Text SUmmarization
